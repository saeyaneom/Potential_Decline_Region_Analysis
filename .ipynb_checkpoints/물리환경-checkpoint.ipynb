# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Data/국토교통부_잠재력지표_2021.csv", encoding="cp949", engine = "python")
df2 = pd.read_excel("Data/활성화지역진단 결과_2022-06-11 (1).xls")

# %%
idx_df1 = df1[df1["연도"] != 2019].index
df1_1 = df1.drop(idx_df1)
df1_1
# Out:
#       시군구코드    연도        시군구명  대졸인구비율  대졸인구비율등급  여성종사자비율  여성종사자비율등급  \
# 257   11140  2019    서울특별시 중구     NaN       NaN    45.61        6.0
# 258   11230  2019  서울특별시 동대문구     NaN       NaN    48.16        6.0
# 259   11260  2019   서울특별시 중랑구     NaN       NaN    50.84        6.0
# 260   11305  2019   서울특별시 강북구     NaN       NaN    56.81        6.0
# 261   11320  2019   서울특별시 도봉구     NaN       NaN    50.69        6.0
# ...     ...   ...         ...     ...       ...      ...        ...
# 2492  46880  2019    전라남도 장성군     NaN       NaN    36.51        5.0
# 2493  46890  2019    전라남도 완도군     NaN       NaN    44.87        6.0
# 2494  46910  2019    전라남도 신안군     NaN       NaN    39.68        5.0
# 2495  47920  2019    경상북도 봉화군     NaN       NaN    30.42        5.0
# 2496  48730  2019    경상남도 함안군     NaN       NaN    29.15        5.0
#
#       20세미만인구성장률  20세미만인구성장률등급  투표율  ...  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  \
# 257        -4.95          10.0  NaN  ...    81.09        5.0         6.33
# ...

# %%
df2_1 = df2.replace(['O', 'X'], ['1', '0'])
df2_1
# Out:
#          시도명          시군구명       최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  \
# 0      서울특별시     서울특별시 종로구     서울특별시 종로구    1    1    1   -45.047       2
# 1      서울특별시      서울특별시 중구      서울특별시 중구    1    1    1   -43.708       2
# 2      서울특별시     서울특별시 용산구     서울특별시 용산구    1    0    1   -34.927       4
# 3      서울특별시     서울특별시 성동구     서울특별시 성동구    1    0    1   -31.230       1
# 4      서울특별시     서울특별시 광진구     서울특별시 광진구    0    0    1    -8.694       2
# ..       ...           ...           ...  ...  ...  ...       ...     ...
# 191     경상남도      경상남도 함양군      경상남도 함양군    1    0    1   -46.142       5
# 192     경상남도      경상남도 거창군      경상남도 거창군    1    0    1   -34.529       2
# 193     경상남도      경상남도 합천군      경상남도 합천군    1    1    1   -55.243       5
# 194  제주특별자치도   제주특별자치도 제주시   제주특별자치도 제주시    0    0    1     9.994       0
# 195  제주특별자치도  제주특별자치도 서귀포시  제주특별자치도 서귀포시    0    0    1   -13.827       0
#
#      과거대비사업체변화  최근사업체변화  노후건축물비율
# 0       -2.564        4   76.602
# ...

# %%
merge_data = pd.merge(df2_1, df1_1, on = '시군구명', how = 'outer')
merge_data
# Out:
#        시도명       시군구명    최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  \
# 0    서울특별시  서울특별시 종로구  서울특별시 종로구    1    1    1   -45.047     2.0     -2.564
# 1    서울특별시   서울특별시 중구   서울특별시 중구    1    1    1   -43.708     2.0     -7.973
# 2    서울특별시  서울특별시 용산구  서울특별시 용산구    1    0    1   -34.927     4.0     -1.781
# 3    서울특별시  서울특별시 성동구  서울특별시 성동구    1    0    1   -31.230     1.0      2.660
# 4    서울특별시  서울특별시 광진구  서울특별시 광진구    0    0    1    -8.694     2.0     -1.620
# ..     ...        ...        ...  ...  ...  ...       ...     ...        ...
# 224    NaN   충청남도 아산시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 225    NaN   충청남도 당진시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 226    NaN   경상남도 김해시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 227    NaN  부산광역시 기장군        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 228    NaN   충청남도 계룡시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
#
# ...

# %%
merge_data.drop("시도명", axis = 1, inplace = True)
merge_data
# Out:
#           시군구명    최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1    1    1   -45.047     2.0     -2.564
# 1     서울특별시 중구   서울특별시 중구    1    1    1   -43.708     2.0     -7.973
# 2    서울특별시 용산구  서울특별시 용산구    1    0    1   -34.927     4.0     -1.781
# 3    서울특별시 성동구  서울특별시 성동구    1    0    1   -31.230     1.0      2.660
# 4    서울특별시 광진구  서울특별시 광진구    0    0    1    -8.694     2.0     -1.620
# ..         ...        ...  ...  ...  ...       ...     ...        ...
# 224   충청남도 아산시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 225   충청남도 당진시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 226   경상남도 김해시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 227  부산광역시 기장군        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 228   충청남도 계룡시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
#
#      최근사업체변화  노후건축물비율  ...  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  1만인당사회복지시설수등급  \
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시군구명            229 non-null    object
#  1   최종 선정지역         196 non-null    object
#  2   인구사회            196 non-null    object
#  3   산업경제            196 non-null    object
#  4   물리환경            196 non-null    object
#  5   과거대비인구변화        196 non-null    float64
#  6   최근인구변화          196 non-null    float64
#  7   과거대비사업체변화       196 non-null    float64
#  8   최근사업체변화         196 non-null    float64
#  9   노후건축물비율         196 non-null    float64
#  10  시군구코드           229 non-null    int64
#  11  연도              229 non-null    int64
#  12  대졸인구비율          0 non-null      float64
#  13  대졸인구비율등급        0 non-null      float64
#  14  여성종사자비율         229 non-null    float64
#  15  여성종사자비율등급       229 non-null    float64
#  16  20세미만인구성장률      229 non-null    float64
# ...

# %%
merge_data['시도명'] =[""]*len(merge_data)

# %%
for i in range(len(merge_data)):
    si = merge_data.iloc[i, 0].split()
    merge_data.iloc[i, 50] = si[0]

# %%
merge_data.drop(['투표율', '투표율등급', '비영리단체수', '비영리단체수등급'], axis = 1, inplace=True)
merge_data
# Out:
#           시군구명    최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1    1    1   -45.047     2.0     -2.564
# 1     서울특별시 중구   서울특별시 중구    1    1    1   -43.708     2.0     -7.973
# 2    서울특별시 용산구  서울특별시 용산구    1    0    1   -34.927     4.0     -1.781
# 3    서울특별시 성동구  서울특별시 성동구    1    0    1   -31.230     1.0      2.660
# 4    서울특별시 광진구  서울특별시 광진구    0    0    1    -8.694     2.0     -1.620
# ..         ...        ...  ...  ...  ...       ...     ...        ...
# 224   충청남도 아산시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 225   충청남도 당진시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 226   경상남도 김해시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 227  부산광역시 기장군        NaN  NaN  NaN  NaN       NaN     NaN        NaN
# 228   충청남도 계룡시        NaN  NaN  NaN  NaN       NaN     NaN        NaN
#
#      최근사업체변화  노후건축물비율  ...  주민등록인구전출입률등급  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  \
# ...

# %%
merge_data.loc[merge_data['인구사회'] != merge_data['인구사회'], '인구사회'] = '0'
merge_data
# Out:
#           시군구명    최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1    1    1   -45.047     2.0     -2.564
# 1     서울특별시 중구   서울특별시 중구    1    1    1   -43.708     2.0     -7.973
# 2    서울특별시 용산구  서울특별시 용산구    1    0    1   -34.927     4.0     -1.781
# 3    서울특별시 성동구  서울특별시 성동구    1    0    1   -31.230     1.0      2.660
# 4    서울특별시 광진구  서울특별시 광진구    0    0    1    -8.694     2.0     -1.620
# ..         ...        ...  ...  ...  ...       ...     ...        ...
# 224   충청남도 아산시        NaN    0  NaN  NaN       NaN     NaN        NaN
# 225   충청남도 당진시        NaN    0  NaN  NaN       NaN     NaN        NaN
# 226   경상남도 김해시        NaN    0  NaN  NaN       NaN     NaN        NaN
# 227  부산광역시 기장군        NaN    0  NaN  NaN       NaN     NaN        NaN
# 228   충청남도 계룡시        NaN    0  NaN  NaN       NaN     NaN        NaN
#
#      최근사업체변화  노후건축물비율  ...  주민등록인구전출입률등급  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  \
# ...

# %%
merge_data.loc[merge_data['산업경제'] != merge_data['산업경제'], '산업경제'] = '0'
merge_data.loc[merge_data['물리환경'] != merge_data['물리환경'], '물리환경'] = '0'
merge_data
# Out:
#           시군구명    최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1    1    1   -45.047     2.0     -2.564
# 1     서울특별시 중구   서울특별시 중구    1    1    1   -43.708     2.0     -7.973
# 2    서울특별시 용산구  서울특별시 용산구    1    0    1   -34.927     4.0     -1.781
# 3    서울특별시 성동구  서울특별시 성동구    1    0    1   -31.230     1.0      2.660
# 4    서울특별시 광진구  서울특별시 광진구    0    0    1    -8.694     2.0     -1.620
# ..         ...        ...  ...  ...  ...       ...     ...        ...
# 224   충청남도 아산시        NaN    0    0    0       NaN     NaN        NaN
# 225   충청남도 당진시        NaN    0    0    0       NaN     NaN        NaN
# 226   경상남도 김해시        NaN    0    0    0       NaN     NaN        NaN
# 227  부산광역시 기장군        NaN    0    0    0       NaN     NaN        NaN
# 228   충청남도 계룡시        NaN    0    0    0       NaN     NaN        NaN
#
#      최근사업체변화  노후건축물비율  ...  주민등록인구전출입률등급  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  \
# ...

# %%
merge_data[merge_data['과거대비인구변화'].isnull()]
# Out:
#           시군구명 최종 선정지역 인구사회 산업경제 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  최근사업체변화  \
# 196    경기도 고양시     NaN    0    0    0       NaN     NaN        NaN      NaN
# 197   인천광역시 중구     NaN    0    0    0       NaN     NaN        NaN      NaN
# 198  인천광역시 옹진군     NaN    0    0    0       NaN     NaN        NaN      NaN
# 199   울산광역시 북구     NaN    0    0    0       NaN     NaN        NaN      NaN
# 200    경기도 하남시     NaN    0    0    0       NaN     NaN        NaN      NaN
# 201    경기도 안성시     NaN    0    0    0       NaN     NaN        NaN      NaN
# 202    경기도 가평군     NaN    0    0    0       NaN     NaN        NaN      NaN
# 203    경기도 양평군     NaN    0    0    0       NaN     NaN        NaN      NaN
# 204   경상북도 구미시     NaN    0    0    0       NaN     NaN        NaN      NaN
# 205  대전광역시 유성구     NaN    0    0    0       NaN     NaN        NaN      NaN
# 206    경기도 평택시     NaN    0    0    0       NaN     NaN        NaN      NaN
# ...

# %%
merge_data.drop(['인구사회', '산업경제'], axis = 1, inplace = True)
merge_data
# Out:
#           시군구명    최종 선정지역 물리환경  과거대비인구변화  최근인구변화  과거대비사업체변화  최근사업체변화  노후건축물비율  \
# 0    서울특별시 종로구  서울특별시 종로구    1   -45.047     2.0     -2.564      4.0   76.602
# 1     서울특별시 중구   서울특별시 중구    1   -43.708     2.0     -7.973      3.0   83.795
# 2    서울특별시 용산구  서울특별시 용산구    1   -34.927     4.0     -1.781      2.0   82.572
# 3    서울특별시 성동구  서울특별시 성동구    1   -31.230     1.0      2.660      0.0   80.584
# 4    서울특별시 광진구  서울특별시 광진구    1    -8.694     2.0     -1.620      2.0   71.326
# ..         ...        ...  ...       ...     ...        ...      ...      ...
# 224   충청남도 아산시        NaN    0       NaN     NaN        NaN      NaN      NaN
# 225   충청남도 당진시        NaN    0       NaN     NaN        NaN      NaN      NaN
# 226   경상남도 김해시        NaN    0       NaN     NaN        NaN      NaN      NaN
# 227  부산광역시 기장군        NaN    0       NaN     NaN        NaN      NaN      NaN
# 228   충청남도 계룡시        NaN    0       NaN     NaN        NaN      NaN      NaN
#
# ...

# %%
merge_data['과거대비인구변화'] = merge_data['과거대비인구변화'].fillna(merge_data.groupby(['시도명'])['과거대비인구변화'].transform('mean'))
merge_data['최근인구변화'] = merge_data['최근인구변화'].fillna(merge_data.groupby(['시도명'])['최근인구변화'].transform('mean'))
merge_data['과거대비사업체변화'] = merge_data['과거대비사업체변화'].fillna(merge_data.groupby(['시도명'])['과거대비사업체변화'].transform('mean'))
merge_data['최근사업체변화'] = merge_data['최근사업체변화'].fillna(merge_data.groupby(['시도명'])['최근사업체변화'].transform('mean'))
merge_data
# Out:
#           시군구명    최종 선정지역 물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1 -45.047000  2.000000  -2.564000  4.000000
# 1     서울특별시 중구   서울특별시 중구    1 -43.708000  2.000000  -7.973000  3.000000
# 2    서울특별시 용산구  서울특별시 용산구    1 -34.927000  4.000000  -1.781000  2.000000
# 3    서울특별시 성동구  서울특별시 성동구    1 -31.230000  1.000000   2.660000  0.000000
# 4    서울특별시 광진구  서울특별시 광진구    1  -8.694000  2.000000  -1.620000  2.000000
# ..         ...        ...  ...        ...       ...        ...       ...
# 224   충청남도 아산시        NaN    0 -32.106583  3.333333   2.468667  0.583333
# 225   충청남도 당진시        NaN    0 -32.106583  3.333333   2.468667  0.583333
# 226   경상남도 김해시        NaN    0 -29.460000  3.812500   1.712187  0.625000
# 227  부산광역시 기장군        NaN    0 -26.445714  4.071429  -0.213071  1.000000
# 228   충청남도 계룡시        NaN    0 -32.106583  3.333333   2.468667  0.583333
#
#      노후건축물비율  시군구코드    연도  ...  주민등록인구전출입률등급  폐기물재활용률  폐기물재활용률등급  1만인당사회복지시설수  \
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 228
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시군구명            229 non-null    object
#  1   최종 선정지역         196 non-null    object
#  2   물리환경            229 non-null    object
#  3   과거대비인구변화        229 non-null    float64
#  4   최근인구변화          229 non-null    float64
#  5   과거대비사업체변화       229 non-null    float64
#  6   최근사업체변화         229 non-null    float64
#  7   노후건축물비율         196 non-null    float64
#  8   시군구코드           229 non-null    int64
#  9   연도              229 non-null    int64
#  10  대졸인구비율          0 non-null      float64
#  11  대졸인구비율등급        0 non-null      float64
#  12  여성종사자비율         229 non-null    float64
#  13  여성종사자비율등급       229 non-null    float64
#  14  20세미만인구성장률      229 non-null    float64
#  15  20세미만인구성장률등급    229 non-null    float64
#  16  재정자립도           229 non-null    float64
# ...

# %%
merge_data.drop(merge_data.columns[range(11, 44, 2)], axis = 1, inplace = True)
merge_data
# Out:
#           시군구명    최종 선정지역 물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화  \
# 0    서울특별시 종로구  서울특별시 종로구    1 -45.047000  2.000000  -2.564000  4.000000
# 1     서울특별시 중구   서울특별시 중구    1 -43.708000  2.000000  -7.973000  3.000000
# 2    서울특별시 용산구  서울특별시 용산구    1 -34.927000  4.000000  -1.781000  2.000000
# 3    서울특별시 성동구  서울특별시 성동구    1 -31.230000  1.000000   2.660000  0.000000
# 4    서울특별시 광진구  서울특별시 광진구    1  -8.694000  2.000000  -1.620000  2.000000
# ..         ...        ...  ...        ...       ...        ...       ...
# 224   충청남도 아산시        NaN    0 -32.106583  3.333333   2.468667  0.583333
# 225   충청남도 당진시        NaN    0 -32.106583  3.333333   2.468667  0.583333
# 226   경상남도 김해시        NaN    0 -29.460000  3.812500   1.712187  0.625000
# 227  부산광역시 기장군        NaN    0 -26.445714  4.071429  -0.213071  1.000000
# 228   충청남도 계룡시        NaN    0 -32.106583  3.333333   2.468667  0.583333
#
#      노후건축물비율  시군구코드    연도  ...  1인당공원면적   도로밀도  1만인당공무원수  건축허가면적증감률  \
# ...

# %%
merge_data.drop(['최종 선정지역'], axis = 1, inplace=True)

# %%
merge_data.drop(['여성종사자비율'], axis = 1, inplace = True)

# %%
merge_data['노후건축물비율'] = merge_data['노후건축물비율'].fillna(merge_data.groupby(['시도명'])['노후건축물비율'].transform('mean'))
merge_data['대졸인구비율'] = merge_data['대졸인구비율'].fillna(merge_data.groupby(['시도명'])['대졸인구비율'].transform('mean'))
merge_data['20세미만인구성장률'] = merge_data['20세미만인구성장률'].fillna(merge_data.groupby(['시도명'])['20세미만인구성장률'].transform('mean'))
merge_data['재정자립도'] = merge_data['재정자립도'].fillna(merge_data.groupby(['시도명'])['재정자립도'].transform('mean'))
merge_data['경제활동인구대비종사자수'] = merge_data['경제활동인구대비종사자수'].fillna(merge_data.groupby(['시도명'])['경제활동인구대비종사자수'].transform('mean'))
merge_data['1인당지역내총생산'] = merge_data['1인당지역내총생산'].fillna(merge_data.groupby(['시도명'])['1인당지역내총생산'].transform('mean'))
merge_data['특허출원건수'] = merge_data['특허출원건수'].fillna(merge_data.groupby(['시도명'])['특허출원건수'].transform('mean'))
merge_data['1인당주민세'] = merge_data['1인당주민세'].fillna(merge_data.groupby(['시도명'])['1인당주민세'].transform('mean'))
merge_data['1인당공원면적'] = merge_data['1인당공원면적'].fillna(merge_data.groupby(['시도명'])['1인당공원면적'].transform('mean'))
merge_data['도로밀도'] = merge_data['도로밀도'].fillna(merge_data.groupby(['시도명'])['도로밀도'].transform('mean'))
merge_data['1만인당공무원수'] = merge_data['1만인당공무원수'].fillna(merge_data.groupby(['시도명'])['1만인당공무원수'].transform('mean'))
merge_data['건축허가면적증감률'] = merge_data['건축허가면적증감률'].fillna(merge_data.groupby(['시도명'])['건축허가면적증감률'].transform('mean'))
merge_data['주민등록인구전출입률'] = merge_data['주민등록인구전출입률'].fillna(merge_data.groupby(['시도명'])['주민등록인구전출입률'].transform('mean'))
merge_data['폐기물재활용률'] = merge_data['폐기물재활용률'].fillna(merge_data.groupby(['시도명'])['폐기물재활용률'].transform('mean'))
merge_data['1만인당사회복지시설수'] = merge_data['1만인당사회복지시설수'].fillna(merge_data.groupby(['시도명'])['1만인당사회복지시설수'].transform('mean'))
merge_data['1만인당문화체육시설수'] = merge_data['1만인당문화체육시설수'].fillna(merge_data.groupby(['시도명'])['1만인당문화체육시설수'].transform('mean'))
merge_data['1만인당축제건수'] = merge_data['1만인당축제건수'].fillna(merge_data.groupby(['시도명'])['1만인당축제건수'].transform('mean'))

# %%
merge_data
# Out:
#           시군구명 물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율  \
# 0    서울특별시 종로구    1 -45.047000  2.000000  -2.564000  4.000000  76.602000
# 1     서울특별시 중구    1 -43.708000  2.000000  -7.973000  3.000000  83.795000
# 2    서울특별시 용산구    1 -34.927000  4.000000  -1.781000  2.000000  82.572000
# 3    서울특별시 성동구    1 -31.230000  1.000000   2.660000  0.000000  80.584000
# 4    서울특별시 광진구    1  -8.694000  2.000000  -1.620000  2.000000  71.326000
# ..         ...  ...        ...       ...        ...       ...        ...
# 224   충청남도 아산시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 225   충청남도 당진시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 226   경상남도 김해시    0 -29.460000  3.812500   1.712187  0.625000  61.195813
# 227  부산광역시 기장군    0 -26.445714  4.071429  -0.213071  1.000000  80.670857
# 228   충청남도 계룡시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
#
#      시군구코드    연도  대졸인구비율  ...  1인당공원면적   도로밀도  1만인당공무원수  건축허가면적증감률  \
# ...

# %%
merge_data.drop('대졸인구비율', axis = 1, inplace=True)

# %%
merge_data
# Out:
#           시군구명 물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율  \
# 0    서울특별시 종로구    1 -45.047000  2.000000  -2.564000  4.000000  76.602000
# 1     서울특별시 중구    1 -43.708000  2.000000  -7.973000  3.000000  83.795000
# 2    서울특별시 용산구    1 -34.927000  4.000000  -1.781000  2.000000  82.572000
# 3    서울특별시 성동구    1 -31.230000  1.000000   2.660000  0.000000  80.584000
# 4    서울특별시 광진구    1  -8.694000  2.000000  -1.620000  2.000000  71.326000
# ..         ...  ...        ...       ...        ...       ...        ...
# 224   충청남도 아산시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 225   충청남도 당진시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 226   경상남도 김해시    0 -29.460000  3.812500   1.712187  0.625000  61.195813
# 227  부산광역시 기장군    0 -26.445714  4.071429  -0.213071  1.000000  80.670857
# 228   충청남도 계룡시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
#
#      시군구코드    연도  20세미만인구성장률  ...  1인당공원면적   도로밀도  1만인당공무원수  건축허가면적증감률  \
# ...

# %%
merge_data
# Out:
#           시군구명 물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율  \
# 0    서울특별시 종로구    1 -45.047000  2.000000  -2.564000  4.000000  76.602000
# 1     서울특별시 중구    1 -43.708000  2.000000  -7.973000  3.000000  83.795000
# 2    서울특별시 용산구    1 -34.927000  4.000000  -1.781000  2.000000  82.572000
# 3    서울특별시 성동구    1 -31.230000  1.000000   2.660000  0.000000  80.584000
# 4    서울특별시 광진구    1  -8.694000  2.000000  -1.620000  2.000000  71.326000
# ..         ...  ...        ...       ...        ...       ...        ...
# 224   충청남도 아산시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 225   충청남도 당진시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
# 226   경상남도 김해시    0 -29.460000  3.812500   1.712187  0.625000  61.195813
# 227  부산광역시 기장군    0 -26.445714  4.071429  -0.213071  1.000000  80.670857
# 228   충청남도 계룡시    0 -32.106583  3.333333   2.468667  0.583333  56.826000
#
#      시군구코드    연도  20세미만인구성장률  ...  1인당공원면적   도로밀도  1만인당공무원수  건축허가면적증감률  \
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 228
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시군구명          229 non-null    object
#  1   물리환경          229 non-null    object
#  2   과거대비인구변화      229 non-null    float64
#  3   최근인구변화        229 non-null    float64
#  4   과거대비사업체변화     229 non-null    float64
#  5   최근사업체변화       229 non-null    float64
#  6   노후건축물비율       229 non-null    float64
#  7   시군구코드         229 non-null    int64
#  8   연도            229 non-null    int64
#  9   20세미만인구성장률    229 non-null    float64
#  10  재정자립도         229 non-null    float64
#  11  경제활동인구대비종사자수  229 non-null    float64
#  12  1인당지역내총생산     0 non-null      float64
#  13  특허출원건수        229 non-null    float64
#  14  1인당주민세        229 non-null    float64
#  15  1인당공원면적       229 non-null    float64
#  16  도로밀도          229 non-null    float64
# ...

# %%
merge_data.drop("시도명", axis = 1, inplace=True)

# %%
merge_data.drop("1인당지역내총생산", axis = 1, inplace=True)

# %%
merge_data['시군구코드'] = merge_data['시군구코드'].astype(float)

# %%
merge_data['최근인구변화'] = merge_data['최근인구변화'].astype(float)

# %%
merge_data['물리환경'] = merge_data['물리환경'].astype(float)

# %%
merge_data.drop("연도", axis = 1, inplace=True)

# %%
merge_data['1만인당사회복지시설수'] = merge_data['1만인당사회복지시설수'].fillna(merge_data['1만인당사회복지시설수'].mean())
merge_data['폐기물재활용률'] = merge_data['폐기물재활용률'].fillna(merge_data['폐기물재활용률'].mean())
merge_data['건축허가면적증감률'] = merge_data['건축허가면적증감률'].fillna(merge_data['건축허가면적증감률'].mean())

# %%
merge_data.to_csv("물리경제.csv", encoding="cp949")

# %%
from sklearn.model_selection import train_test_split

feature_columns = merge_data.columns.difference(['물리환경', '시군구명'])

X = merge_data[feature_columns]
y = merge_data['물리환경']

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 229 entries, 0 to 228
# Series name: 물리환경
# Non-Null Count  Dtype
# --------------  -----
# 229 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB

# %%
import statsmodels.api as sm

full_model = sm.OLS(y, X)
fitted_full_model = full_model.fit()

fitted_full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   물리환경   R-squared (uncentered):                   0.861
# Model:                            OLS   Adj. R-squared (uncentered):              0.848
# Method:                 Least Squares   F-statistic:                              64.72
# Date:                Mon, 13 Jun 2022   Prob (F-statistic):                    4.64e-78
# Time:                        16:14:10   Log-Likelihood:                         -67.564
# No. Observations:                 229   AIC:                                      175.1
# Df Residuals:                     209   BIC:                                      243.8
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
def stepwise_feature_selection(X_train, y_train, variables=X.columns.tolist() ):
    import statsmodels.api as sm
    import matplotlib.pyplot as plt
    import warnings
    warnings.filterwarnings("ignore")
    
    y = y_train ## 반응 변수

    selected_variables = [] ## 선택된 변수들
    sl_enter = 0.05
    sl_remove = 0.05
    
    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(variables) > 0:
        remainder = list(set(variables) - set(selected_variables))
        pval = pd.Series(index=remainder) ## 변수의 p-value
        ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
        ## 선형 모형을 적합한다.
        for col in remainder: 
            X = X_train[selected_variables+[col]]
            X = sm.add_constant(X)
            model = sm.OLS(y,X).fit(disp=0)
            pval[col] = model.pvalues[col]
    
        min_pval = pval.min()
        if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
            selected_variables.append(pval.idxmin())
            ## 선택된 변수들에대해서
            ## 어떤 변수를 제거할지 고른다.
            while len(selected_variables) > 0:
                selected_X = X_train[selected_variables]
                selected_X = sm.add_constant(selected_X)
                selected_pval = sm.OLS(y,selected_X).fit(disp=0).pvalues[1:] ## 절편항의 p-value는 뺀다
                max_pval = selected_pval.max()
                if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                    remove_variable = selected_pval.idxmax()
                    selected_variables.remove(remove_variable)
                else:
                    break
            
            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y,sm.add_constant(X_train[selected_variables])).fit(disp=0).rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break

    fig = plt.figure(figsize=(100,10))
    fig.set_facecolor('white')
    
    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
    plt.plot(steps,adjusted_r_squared, marker='o')
      
    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()

    return selected_variables
    

selected_variables = stepwise_feature_selection(X, y)

# %%
import statsmodels.api as sm
model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[selected_variables]))).fit(disp=0)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   물리환경   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     32.70
# Date:                Mon, 13 Jun 2022   Prob (F-statistic):           1.80e-21
# Time:                        16:14:29   Log-Likelihood:                -77.508
# No. Observations:                 229   AIC:                             165.0
# Df Residuals:                     224   BIC:                             182.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0863      0.147     -0.588      0.557      -0.376       0.203
# ...

# %%
from sklearn.preprocessing import StandardScaler

data = merge_data[['노후건축물비율', '재정자립도', '최근인구변화', '주민등록인구전출입률']]

std = StandardScaler()
std_data = std.fit_transform(data)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,4))
visualizer.fit(std_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py:973, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     970     method = get_real_method(obj, self.print_method)
#     972     if method is not None:
# --> 973         return method(include=include, exclude=exclude)
#     974     return None
#     975 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:614, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     612 def _repr_mimebundle_(self, **kwargs):
#     613     """Mime bundle used by jupyter kernels to display estimator"""
# --> 614     output = {"text/plain": repr(self)}
#     615     if get_config()["display"] == "diagram":
#     616         output["text/html"] = estimator_html_repr(self)
#
# ...

# %%
pip install yellowbrick
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = KMeans(n_clusters =3, random_state = 20)

# %%
from sklearn.cluster import KMeans

k = 3

# 그룹 수, random_state 설정
model = KMeans(n_clusters = k, random_state = 10)

# 정규화된 데이터에 학습
model.fit(std_data)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
merge_data['cluster'] = model.fit_predict(std_data)

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize = (8, 8))

# for i in range(3):
#     plt.scatter(merge_data.loc[df_new['cluster'] == i, '최근인구변화'], df_new.loc[df_new['cluster'] == i, '과거대비인구변화'], 
#                 label = 'cluster ' + str(i))

# plt.legend()
# plt.title('K = %d results'%k , size = 15)
# plt.xlabel('recent', size = 12)
# plt.ylabel('past', size = 12)
# plt.show()

# %%
import folium
import json

# %%
geo_path = "sig_wgs84.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
df_map = merge_data

# %%
df_map['시군구코드'] = df_map.시군구코드.map(lambda x : str(x).zfill(5))

# %%
df_map.drop('시군구명', axis=1, inplace=True)

# %%
df_map
# Out:
#      물리환경   과거대비인구변화    최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율    시군구코드  \
# 0     1.0 -45.047000  2.000000  -2.564000  4.000000  76.602000  11110.0
# 1     1.0 -43.708000  2.000000  -7.973000  3.000000  83.795000  11140.0
# 2     1.0 -34.927000  4.000000  -1.781000  2.000000  82.572000  11170.0
# 3     1.0 -31.230000  1.000000   2.660000  0.000000  80.584000  11200.0
# 4     1.0  -8.694000  2.000000  -1.620000  2.000000  71.326000  11215.0
# ..    ...        ...       ...        ...       ...        ...      ...
# 224   0.0 -32.106583  3.333333   2.468667  0.583333  56.826000  44200.0
# 225   0.0 -32.106583  3.333333   2.468667  0.583333  56.826000  44830.0
# 226   0.0 -29.460000  3.812500   1.712187  0.625000  61.195813  48250.0
# 227   0.0 -26.445714  4.071429  -0.213071  1.000000  80.670857  26710.0
# 228   0.0 -32.106583  3.333333   2.468667  0.583333  56.826000  44250.0
#
#      20세미만인구성장률  재정자립도  경제활동인구대비종사자수  ...  1인당공원면적   도로밀도  1만인당공무원수  \
# ...

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=geo_str,
    name='활성화지표',
    data=df_map,
    columns=['시군구코드', 'cluster'],
    key_on='feature.properties.SIG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'activation'
)

# https://blog.naver.com/yun9706/222454846442

# %%
folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr.html')
