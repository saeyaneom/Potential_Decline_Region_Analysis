# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/산업경제.csv', encoding = 'euc-kr')

# %%
df
# Out:
#      Unnamed: 0       시군구명  산업경제   과거대비인구변화  최근인구변화  과거대비사업체변화   최근사업체변화  \
# 0             0  서울특별시 종로구     1 -45.047000       2  -2.564000  4.000000
# 1             1   서울특별시 중구     1 -43.708000       2  -7.973000  3.000000
# 2             2  서울특별시 용산구     0 -34.927000       4  -1.781000  2.000000
# 3             3  서울특별시 성동구     0 -31.230000       1   2.660000  0.000000
# 4             4  서울특별시 광진구     0  -8.694000       2  -1.620000  2.000000
# ..          ...        ...   ...        ...     ...        ...       ...
# 224         224   충청남도 아산시     0 -32.106583       3   2.468667  0.583333
# 225         225   충청남도 당진시     0 -32.106583       3   2.468667  0.583333
# 226         226   경상남도 김해시     0 -29.460000       3   1.712187  0.625000
# 227         227  부산광역시 기장군     0 -26.445714       4  -0.213071  1.000000
# 228         228   충청남도 계룡시     0 -32.106583       3   2.468667  0.583333
#
#        노후건축물비율  시군구코드    연도  ...  1인당주민세  1인당공원면적   도로밀도  1만인당공무원수  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시군구명          229 non-null    object
#  1   산업경제          229 non-null    int64
#  2   과거대비인구변화      229 non-null    float64
#  3   최근인구변화        229 non-null    int64
#  4   과거대비사업체변화     229 non-null    float64
#  5   최근사업체변화       229 non-null    float64
#  6   노후건축물비율       229 non-null    float64
#  7   시군구코드         229 non-null    int64
#  8   연도            229 non-null    int64
#  9   20세미만인구성장률    229 non-null    float64
#  10  재정자립도         229 non-null    float64
#  11  경제활동인구대비종사자수  229 non-null    float64
#  12  특허출원건수        229 non-null    float64
#  13  1인당주민세        229 non-null    float64
#  14  1인당공원면적       229 non-null    float64
#  15  도로밀도          229 non-null    float64
#  16  1만인당공무원수      229 non-null    float64
#  17  주민등록인구전출입률    229 non-null    float64
# ...

# %%
idx_sg = df[(df['시도명']=='서울특별시') | (df['시도명']=='경기도')].index
df.drop(idx_sg, inplace = True)

# %%
df['1만인당사회복지시설수'] = df['1만인당사회복지시설수'].fillna(df['1만인당사회복지시설수'].mean())
df['폐기물재활용률'] = df['폐기물재활용률'].fillna(df['폐기물재활용률'].mean())

# %%
df.drop(['연도', '시도명'], axis=1, inplace = True)
# df_new.set_index('시군구명', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 25 to 228
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시군구명          173 non-null    object
#  1   산업경제          173 non-null    int64
#  2   과거대비인구변화      173 non-null    float64
#  3   최근인구변화        173 non-null    int64
#  4   과거대비사업체변화     173 non-null    float64
#  5   최근사업체변화       173 non-null    float64
#  6   노후건축물비율       173 non-null    float64
#  7   시군구코드         173 non-null    int64
#  8   20세미만인구성장률    173 non-null    float64
#  9   재정자립도         173 non-null    float64
#  10  경제활동인구대비종사자수  173 non-null    float64
#  11  특허출원건수        173 non-null    float64
#  12  1인당주민세        173 non-null    float64
#  13  1인당공원면적       173 non-null    float64
#  14  도로밀도          173 non-null    float64
#  15  1만인당공무원수      173 non-null    float64
#  16  주민등록인구전출입률    173 non-null    float64
# ...

# %%
from sklearn.model_selection import train_test_split

feature_columns = df.columns.difference(['산업경제', '시군구명', '시군구코드'])

X = df[feature_columns]
y = df['산업경제']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 25 to 228
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1만인당공무원수      173 non-null    float64
#  1   1만인당문화체육시설수   173 non-null    float64
#  2   1만인당사회복지시설수   173 non-null    float64
#  3   1만인당축제건수      173 non-null    float64
#  4   1인당공원면적       173 non-null    float64
#  5   1인당주민세        173 non-null    float64
#  6   20세미만인구성장률    173 non-null    float64
#  7   경제활동인구대비종사자수  173 non-null    float64
#  8   과거대비사업체변화     173 non-null    float64
#  9   과거대비인구변화      173 non-null    float64
#  10  노후건축물비율       173 non-null    float64
#  11  도로밀도          173 non-null    float64
#  12  재정자립도         173 non-null    float64
#  13  주민등록인구전출입률    173 non-null    float64
#  14  최근사업체변화       173 non-null    float64
#  15  최근인구변화        173 non-null    int64
#  16  특허출원건수        173 non-null    float64
# ...

# %%
import statsmodels.api as sm

full_model = sm.OLS(y, X)
fitted_full_model = full_model.fit()

fitted_full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   산업경제   R-squared (uncentered):                   0.307
# Model:                            OLS   Adj. R-squared (uncentered):              0.227
# Method:                 Least Squares   F-statistic:                              3.817
# Date:                Mon, 13 Jun 2022   Prob (F-statistic):                    2.30e-06
# Time:                        17:32:59   Log-Likelihood:                          136.99
# No. Observations:                 173   AIC:                                     -238.0
# Df Residuals:                     155   BIC:                                     -181.2
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
def stepwise_feature_selection(X_train, y_train, variables=X.columns.tolist() ):
    import statsmodels.api as sm
    import matplotlib.pyplot as plt
    import warnings
    warnings.filterwarnings("ignore")
    
    y = y_train ## 반응 변수

    selected_variables = [] ## 선택된 변수들
    sl_enter = 0.05
    sl_remove = 0.05
    
    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(variables) > 0:
        remainder = list(set(variables) - set(selected_variables))
        pval = pd.Series(index=remainder) ## 변수의 p-value
        ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
        ## 선형 모형을 적합한다.
        for col in remainder: 
            X = X_train[selected_variables+[col]]
            X = sm.add_constant(X)
            model = sm.OLS(y,X).fit(disp=0)
            pval[col] = model.pvalues[col]
    
        min_pval = pval.min()
        if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
            selected_variables.append(pval.idxmin())
            ## 선택된 변수들에대해서
            ## 어떤 변수를 제거할지 고른다.
            while len(selected_variables) > 0:
                selected_X = X_train[selected_variables]
                selected_X = sm.add_constant(selected_X)
                selected_pval = sm.OLS(y,selected_X).fit(disp=0).pvalues[1:] ## 절편항의 p-value는 뺀다
                max_pval = selected_pval.max()
                if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                    remove_variable = selected_pval.idxmax()
                    selected_variables.remove(remove_variable)
                else:
                    break
            
            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y,sm.add_constant(X_train[selected_variables])).fit(disp=0).rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break

    fig = plt.figure(figsize=(100,10))
    fig.set_facecolor('white')
    
    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
    plt.plot(steps,adjusted_r_squared, marker='o')
      
    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()

    return selected_variables
    

selected_variables = stepwise_feature_selection(X, y)

# %%
import statsmodels.api as sm
model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[selected_variables]))).fit(disp=0)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   산업경제   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     18.49
# Date:                Mon, 13 Jun 2022   Prob (F-statistic):           2.02e-10
# Time:                        17:33:01   Log-Likelihood:                 131.32
# No. Observations:                 173   AIC:                            -254.6
# Df Residuals:                     169   BIC:                            -242.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0986      0.019      5.326      0.000       0.062       0.135
# ...

# %%
from sklearn.preprocessing import StandardScaler

data = df[['과거대비사업체변화', '주민등록인구전출입률',  '1인당주민세']]

std = StandardScaler()
std_data = std.fit_transform(data)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))
visualizer.fit(std_data)
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=None)

# %%
model = KMeans(n_clusters =3, random_state = 20)

# %%
from sklearn.cluster import KMeans

k = 3

# 그룹 수, random_state 설정
model = KMeans(n_clusters = k, random_state = 10)

# 정규화된 데이터에 학습
model.fit(std_data)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
df['cluster'] = model.fit_predict(std_data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 8))

for i in range(3):
    plt.scatter(df.loc[df['cluster'] == i, '최근인구변화'], df.loc[df['cluster'] == i, '과거대비인구변화'],
                df.loc[df['cluster'] == i, '재정자립도'],
                label = 'cluster ' + str(i))

plt.legend()
plt.title('K = %d results'%k , size = 15)
plt.xlabel('recent', size = 12)
plt.ylabel('past', size = 12)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(5, 5))

  # 3D axes를 만들기 위해 projection=’3d’ 키워드를 입력해줍니다.
ax = fig.gca(projection='3d')

  # scatter() 함수에 준비된 x, y, z 배열 값을 입력해주고 
  # 마커, 스타일 및 마커 색상 등을 설정할 수 있습니다.
  # marker = 점의 형태
  # s = 점의 크기
  # c = 점의 색깔
ax.scatter(df.loc[df['cluster'] == 1, '과거대비사업체변화'], df.loc[df['cluster'] == 1, '주민등록인구전출입률'],
                df.loc[df['cluster'] == 1, '1인당주민세'], marker='o', s=15, c='darkgreen')
ax.scatter(df.loc[df['cluster'] == 2, '과거대비사업체변화'], df.loc[df['cluster'] == 2, '주민등록인구전출입률'],
                df.loc[df['cluster'] == 2, '1인당주민세'], marker='o', s=15, c='red')
ax.scatter(df.loc[df['cluster'] == 0, '과거대비사업체변화'], df.loc[df['cluster'] == 0, '주민등록인구전출입률'],
                df.loc[df['cluster'] == 0, '1인당주민세'], marker='o', s=15, c='blue')


plt.show()

# %%
df.groupby('cluster')[['과거대비사업체변화', '주민등록인구전출입률', '1인당주민세']].mean()

# 2 : 활성화 상
# 1 : 할성화 하
# 0 : 활성화 중
# Out:
#          과거대비사업체변화  주민등록인구전출입률     1인당주민세
# cluster
# 0         2.899240   -0.302830  31.651981
# 1        -0.596467   -1.409661  29.546271
# 2         2.862110    4.943750  90.962500

# %%
df['cluster'].replace(0, '중', inplace = True)
df['cluster'].replace(1, '하', inplace = True)
df['cluster'].replace(2, '상', inplace = True)

df['cluster'].replace('하', 0, inplace = True)
df['cluster'].replace('중', 1, inplace = True)
df['cluster'].replace('상', 2, inplace = True)

# %%
import seaborn as sns

temp = df.groupby(['cluster']).mean()
cluster_mean = temp.transpose()
mean_table = cluster_mean.div(cluster_mean.max(axis=1), axis=0)

plt.figure(figsize = (20,25))
annot_kws={ 'fontsize' : 12}
sns.heatmap(mean_table,
            annot=True,
            fmt='.3f',
            linewidths=0.1,
            annot_kws = annot_kws,
            cmap='RdYlBu_r')

plt.title('클러스터 X변수 mean table', fontsize = 13)
plt.show()

# %%
figure, ((ax1, ax2, ax3)) = plt.subplots(nrows=3)
sns.boxplot(data= df, y='cluster', x = '최근인구변화', orient = 'h', ax = ax1)
sns.boxplot(data= df, y='cluster', x = '과거대비인구변화', orient = 'h', ax = ax2)
sns.boxplot(data= df, y='cluster', x = '재정자립도', orient = 'h', ax = ax3)
# Out:
# <AxesSubplot:xlabel='재정자립도', ylabel='cluster'>

# %%
df.to_csv('clusterafter산업경제.csv')

# %%
import folium
import json

# %%
geo_path = 'Data/sig_wgs84.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
df_sg = df[['시군구명', '시군구코드']]

# %%
df_clust = df[['시군구명', 'cluster']]

# %%
# df_map = pd.merge(df_sg, df_clust, how='inner', on='시군구명')

# %%
df_map = df

# %%
df_map['시군구코드'] = df_map.시군구코드.map(lambda x : str(x).zfill(5))

# %%
df_map.drop('시군구명', axis=1, inplace=True)

# %%
df_map
# Out:
#      산업경제   과거대비인구변화  최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율  시군구코드  \
# 25      0 -51.989000       5  -1.418000  1.000000  80.871000  26110
# 26      0 -47.947000       3  -3.793000  2.000000  85.443000  26140
# 27      0 -55.607000       5  -3.254000  2.000000  86.257000  26170
# 28      0 -39.292000       5   0.130000  1.000000  83.783000  26200
# 29      0 -27.753000       5   0.653000  0.000000  83.001000  26230
# ..    ...        ...     ...        ...       ...        ...    ...
# 224     0 -32.106583       3   2.468667  0.583333  56.826000  44200
# 225     0 -32.106583       3   2.468667  0.583333  56.826000  44830
# 226     0 -29.460000       3   1.712187  0.625000  61.195813  48250
# 227     0 -26.445714       4  -0.213071  1.000000  80.670857  26710
# 228     0 -32.106583       3   2.468667  0.583333  56.826000  44250
#
#      20세미만인구성장률  재정자립도  경제활동인구대비종사자수  ...  1인당주민세  1인당공원면적  도로밀도  1만인당공무원수  \
# ...

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=geo_str,
    name='활성화지표',
    data=df_map,
    columns=['시군구코드', 'cluster'],
    key_on='feature.properties.SIG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'activation'
)

# https://blog.naver.com/yun9706/222454846442

# %%
folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr_industry.html')

# %%
df[df['cluster']==0]
# Out:
#      산업경제   과거대비인구변화  최근인구변화  과거대비사업체변화   최근사업체변화    노후건축물비율  시군구코드  \
# 25      0 -51.989000       5  -1.418000  1.000000  80.871000  26110
# 26      0 -47.947000       3  -3.793000  2.000000  85.443000  26140
# 27      0 -55.607000       5  -3.254000  2.000000  86.257000  26170
# 28      0 -39.292000       5   0.130000  1.000000  83.783000  26200
# 29      0 -27.753000       5   0.653000  0.000000  83.001000  26230
# 30      0 -21.775000       4  -2.614000  1.000000  82.180000  26260
# 32      0  -9.603000       4   0.114000  0.000000  76.534000  26320
# 34      0 -13.518000       5  -0.169000  1.000000  82.627000  26380
# 35      0 -22.960000       5   0.077000  1.000000  77.082000  26410
# 36      0 -22.899000       2  -0.026000  1.000000  80.542000  26470
# 38      0 -20.415000       5  -0.593000  1.000000  73.537000  26530
# 39      0 -57.701000       2   0.959000  1.000000  80.942000  27110
# 40      0  -6.098000       1   1.047000  0.000000  71.862000  27140
# ...
